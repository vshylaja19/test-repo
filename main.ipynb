# %%
print('Distributions and Aggregations in Data')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('/content/Survey Data.csv')
df.head()

mean_age = df['Age'].mean()
median_age = df['Age'].median()
mode_age = df['Age'].mode()[0]

print('Mean Age:', mean_age)
print('Median Age:', median_age)
print('Mode Age:', mode_age)

fig, ax = plt.subplots(figsize=(6, 4))
ax = sns.histplot(df['Age'], color='skyblue', edgecolor='black')
ax.set_xlabel('Age', fontsize=12)
ax.set_ylabel('Frequency', fontsize=12)
ax.set_title('Distribution of Age')
ax.grid(False)
#sns.despine()
plt.show()

fig, ax = plt.subplots(figsize=(6, 4))
ax = sns.countplot(x='Gender', data=df, palette={'Male':'blue', 'Female':'orange'})
# Add bar labels with adjusted positioning and background color
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 10), textcoords='offset points',
                color='white', bbox=dict(facecolor='black', alpha=0.5))

ax.bar_label(ax.containers[0])
ax.set(xlabel=None, ylabel=None)
#ax.set_ylim(0, 60)
ax.set_ylim(0, df['Gender'].value_counts().max() + 10)  # +10 for some headroom
ax.grid(False)
sns.despine()
plt.title('Gender Distribution')
plt.show()

sns.boxplot(y=df['Income'])
plt.title('Income Distribution')
#plt.xlabel('Education Level')
#plt.ylabel('Count')
plt.show()
# Out:
# Distributions and Aggregations in Data
# Mean Age: 33.36
# Median Age: 32.0
# Mode Age: 29
# <ipython-input-54-70be0ff09c0c>:29: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(x='Gender', data=df, palette={'Male':'blue', 'Female':'orange'})
